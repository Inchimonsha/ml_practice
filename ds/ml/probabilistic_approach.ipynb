# %% [markdown]
# # Вероятностный подход в задачах МО

# %% [markdown]
# > Задания охватывают логистическую регрессию, регуляризацию с вероятностной точки зрения, формулу Байеса, байесовский вывод, наивный байесовский классификатор, гауссовский байесовский классификатор и линейный дискриминант Фишера

# %% [markdown]
# # 1. Логистическая регрессия с вероятностной точки зрения
#
# ## Задание 1: Вероятностная интерпретация логистической регрессии
#
# Описание:
# Вы хотите понять, как логистическая регрессия связана с вероятностью принадлежности объекта к классу.
# Требования:
#
# Используйте датасет Titanic.
# Постройте модель логистической регрессии (sklearn.linear_model.LogisticRegression).
# Получите предсказанные вероятности принадлежности к классу y_pred_proba = model.predict_proba(X_test).
# Визуализируйте распределение вероятностей для каждого класса.
# Объясните, как логистическая функция (сигмоида) связана с вероятностью P(y=1∣x)P(y=1|x)P(y=1∣x).
# Дополнительно:
#
# Постройте калибровочную кривую (sklearn.calibration.calibration_curve) для оценки качества вероятностных предсказаний.
#
# https://www.kaggle.com/c/titanic/data
#
# ## Задание 2: Логистическая регрессия и максимальное правдоподобие
#
# Описание:
# Вы хотите вручную реализовать оценку параметров логистической регрессии методом максимального правдоподобия.
# Требования:
#
# Сгенерируйте синтетические данные для бинарной классификации.
# Запишите функцию правдоподобия для логистической регрессии:
# L(β)=∏i=1nP(yi∣xi,β)=∏i=1n(11+e−xiTβ)yi(1−11+e−xiTβ)1−yi   L(\beta) = \prod_{i=1}^n P(y_i|x_i, \beta) = \prod_{i=1}^n \left( \frac{1}{1 + e^{-x_i^T \beta}} \right)^{y_i} \left(1 - \frac{1}{1 + e^{-x_i^T \beta}} \right)^{1-y_i}L(β)=i=1∏n​P(yi​∣xi​,β)=i=1∏n​(1+e−xiT​β1​)yi​(1−1+e−xiT​β1​)1−yi​
#
# Реализуйте оптимизацию функции правдоподобия с помощью scipy.optimize.minimize.
# Сравните результаты с sklearn.linear_model.LogisticRegression.
# Дополнительно:
#
# Добавьте L2-регуляризацию в функцию правдоподобия.
#
#
#
# # 2. Вероятностный взгляд на L1 и L2-регуляризаторы
#
# ## Задание 3: Байесовская интерпретация L2-регуляризации (Ridge)
#
# Описание:
# Вы хотите понять, как L2-регуляризация связана с байесовским подходом.
# Требования:
#
# Используйте датасет Diabetes.
# Постройте модель Ridge-регрессии (sklearn.linear_model.Ridge).
# Объясните, как L2-регуляризация соответствует байесовскому априорному распределению весов:
# p(w)∼N(0,τ2I)   p(w) \sim \mathcal{N}(0, \tau^2 I)p(w)∼N(0,τ2I)
#
# Визуализируйте распределение весов модели с разными значениями α\alphaα (параметра регуляризации).
# Дополнительно:
#
# Сравните с байесовской регрессией (pymc3 или sklearn.linear_model.BayesianRidge).
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_diabetes.html
#
# ## Задание 4: Байесовская интерпретация L1-регуляризации (Lasso)
#
# Описание:
# Вы хотите понять, как L1-регуляризация связана с априорным распределением Лапласа.
# Требования:
#
# Используйте датасет Boston Housing.
# Постройте модель Lasso (sklearn.linear_model.Lasso).
# Объясните, как L1-регуляризация соответствует априорному распределению:
# p(w)∼Laplace(0,b)   p(w) \sim \text{Laplace}(0, b)p(w)∼Laplace(0,b)
#
# Визуализируйте, как изменяются веса модели при увеличении параметра регуляризации α\alphaα.
# Дополнительно:
#
# Сравните с байесовской регрессией с априорным распределением Лапласа.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_boston.html
#
# # 3. Формула Байеса при решении конкретных задач
#
# ## Задание 5: Применение формулы Байеса для классификации
#
# Описание:
# Вы хотите вручную реализовать байесовский классификатор для простого датасета.
# Требования:
#
# Используйте датасет Play Tennis (погода и решение играть в теннис).
# Реализуйте классификатор на основе формулы Байеса:
# P(y∣X)=P(X∣y)P(y)P(X)   P(y|X) = \frac{P(X|y)P(y)}{P(X)}P(y∣X)=P(X)P(X∣y)P(y)​
#
# Вычислите апостериорные вероятности для каждого класса.
# Сравните результаты с sklearn.naive_bayes.CategoricalNB.
# Дополнительно:
#
# Добавьте сглаживание Лапласа для учёта отсутствующих комбинаций признаков.
#
# https://www.kaggle.com/datasets/heptapod/weather-nominal
#
# ## Задание 6: Байесовское обновление убеждений
#
# Описание:
# Вы хотите смоделировать процесс обновления убеждений на основе новых данных.
# Требования:
#
# Задайте априорное распределение P(H)P(H)P(H) для гипотезы HHH (например, вероятность того, что монета нечестная).
# Сгенерируйте данные (результаты подбрасываний монеты).
# Обновите априорное распределение с помощью формулы Байеса после каждого наблюдения.
# Визуализируйте, как изменяется P(H∣D)P(H|D)P(H∣D) по мере поступления новых данных.
# Дополнительно:
#
# Используйте бета-распределение как сопряжённое априорное распределение.
#
#
#
# # 4. Байесовский вывод
#
# ## Задание 7: Байесовская линейная регрессия
#
# Описание:
# Вы хотите реализовать байесовскую линейную регрессию и сравнить её с классической.
# Требования:
#
# Используйте датасет Boston Housing.
# Задайте априорные распределения для весов и дисперсии:
# w∼N(0,τ2I),σ2∼Inv-Gamma(α,β)   w \sim \mathcal{N}(0, \tau^2 I), \quad \sigma^2 \sim \text{Inv-Gamma}(\alpha, \beta)w∼N(0,τ2I),σ2∼Inv-Gamma(α,β)
#
# Реализуйте байесовский вывод для линейной регрессии (используйте pymc3 или stan).
# Визуализируйте апостериорные распределения весов и сравните с оценками MLE.
# Дополнительно:
#
# Постройте предсказательные интервалы для тестовых объектов.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_boston.html
#
# ## Задание 8: MCMC для байесовского вывода
#
# Описание:
# Вы хотите применить методы Марковской цепи Монте-Карло (MCMC) для байесовского вывода.
# Требования:
#
# Используйте датасет Iris.
# Постройте байесовскую модель логистической регрессии с неинформативными априорными распределениями.
# Примените MCMC (pymc3.sample) для получения апостериорных распределений параметров.
# Визуализируйте цепи Маркова и апостериорные распределения.
# Дополнительно:
#
# Проверьте сходимость цепей с помощью критериев Гевеке (pymc3.diagnostics.gelman_rubin).
#
# https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html
#
# # 5. Наивный байесовский классификатор
#
# ## Задание 9: Реализация наивного байесовского классификатора
#
# Описание:
# Вы хотите вручную реализовать наивный байесовский классификатор для текстов.
# Требования:
#
# Используйте датасет SMS Spam Collection.
# Реализуйте классификатор с нуля:
#
# Вычислите P(y)P(y)P(y) и P(xi∣y)P(x_i|y)P(xi​∣y) для каждого слова xix_ixi​.
# Примените формулу Байеса для классификации новых сообщений.
#
# Сравните результаты с sklearn.naive_bayes.MultinomialNB.
# Дополнительно:
#
# Добавьте сглаживание Лапласа.
#
# https://www.kaggle.com/datasets/uciml/sms-spam-collection-dataset
#
# ## Задание 10: Анализ ошибок наивного байесовского классификатора
#
# Описание:
# Вы хотите проанализировать, на каких примерах наивный байесовский классификатор ошибается чаще всего.
# Требования:
#
# Используйте датасет 20 Newsgroups.
# Обучите sklearn.naive_bayes.MultinomialNB.
# Проанализируйте ошибки классификации:
#
# Постройте матрицу ошибок (sklearn.metrics.confusion_matrix).
# Выведите примеры текстов, где модель ошиблась.
#
# Объясните возможные причины ошибок.
# Дополнительно:
#
# Попробуйте улучшить качество, добавив биграммы.
#
# https://scikit-learn.org/stable/datasets/real_world.html#the-20-newsgroups-text-dataset
#
# # 6. Гауссовский байесовский классификатор
#
# ## Задание 11: Реализация гауссовского наивного байесовского классификатора
#
# Описание:
# Вы хотите реализовать гауссовский наивный байесовский классификатор для непрерывных признаков.
# Требования:
#
# Используйте датасет Wine.
# Реализуйте классификатор с нуля:
#
# Оцените параметры гауссовского распределения для каждого признака в каждом классе.
# Примените формулу Байеса для классификации.
#
# Сравните результаты с sklearn.naive_bayes.GaussianNB.
# Дополнительно:
#
# Визуализируйте гауссовские распределения признаков для каждого класса.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_wine.html
#
# ## Задание 12: Сравнение с другими классификаторами
#
# Описание:
# Вы хотите сравнить гауссовский наивный байесовский классификатор с логистической регрессией и случайным лесом.
# Требования:
#
# Используйте датасет Breast Cancer.
# Обучите три модели:
#
# sklearn.naive_bayes.GaussianNB
# sklearn.linear_model.LogisticRegression
# sklearn.ensemble.RandomForestClassifier
#
# Сравните модели по метрикам:
#
# Accuracy
# Precision
# Recall
# ROC-AUC
#
# Объясните, в каких случаях гауссовский наивный байес работает лучше/хуже других моделей.
# Дополнительно:
#
# Проанализируйте распределения признаков и объясните результаты.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_breast_cancer.html
#
# # 7. Линейный дискриминант Фишера (LDA)
#
# ## Задание 13: Реализация LDA с нуля
#
# Описание:
# Вы хотите вручную реализовать линейный дискриминант Фишера.
# Требования:
#
# Используйте датасет Iris.
# Реализуйте LDA:
#
# Вычислите матрицы рассеяния внутри классов SWS_WSW​ и между классами SBS_BSB​.
# Найдите собственные векторы обобщённой задачи на собственные значения SW−1SBS_W^{-1} S_BSW−1​SB​.
#
# Спроецируйте данные на найденное подпространство и визуализируйте.
# Сравните результаты с sklearn.discriminant_analysis.LinearDiscriminantAnalysis.
# Дополнительно:
#
# Реализуйте квадратичный дискриминантный анализ (QDA).
#
# https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html
#
# ## Задание 14: Применение LDA для снижения размерности
#
# Описание:
# Вы хотите применить LDA для визуализации многомерных данных.
# Требования:
#
# Используйте датасет Wine.
# Примените LDA для снижения размерности до 2D.
# Визуализируйте данные в новом пространстве.
# Сравните с PCA (sklearn.decomposition.PCA).
# Дополнительно:
#
# Объясните, почему LDA лучше подходит для классификации, чем PCA.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_wine.html

# %% [markdown]
# > практические задания для углублённого изучения байесовских сетей, марковских цепей и приближённых байесовских методов
#
# # 8. Байесовские сети (Bayesian Networks)
#
# ## Задание 15: Построение байесовской сети для медицинской диагностики
#
# Описание:
# Вы хотите построить байесовскую сеть для диагностики заболеваний на основе симптомов.
# Требования:
#
# Используйте данные о симптомах и диагнозах (например, Heart Disease Dataset).
# Постройте структуру байесовской сети вручную или с помощью алгоритма обучения структуры (например, pgmpy):
#
# Узлы: симптомы и заболевания.
# Рёбра: зависимости между симптомами и заболеваниями.
#
# Обучите параметры сети с помощью pgmpy.estimators.MaximumLikelihoodEstimator.
# Выполните вывод вероятностей заболеваний при заданных симптомах.
# Дополнительно:
#
# Визуализируйте сеть с помощью pgmpy.models.BayesianNetwork.plot.
#
# https://www.kaggle.com/datasets/johnsmith88/heart-disease-dataset
#
# ## Задание 16: Обучение структуры байесовской сети
#
# Описание:
# Вы хотите автоматически обучать структуру байесовской сети на основе данных.
# Требования:
#
# Используйте датасет Titanic.
# Примените алгоритмы обучения структуры:
#
# pgmpy.estimators.StructureEstimator (например, PC или HillClimbSearch).
#
# Обучите параметры сети и выполните вероятностный вывод.
# Сравните результаты с ручной структурой сети.
# Дополнительно:
#
# Оцените качество сети с помощью кросс-валидации.
#
# https://www.kaggle.com/c/titanic/data
#
# ## Задание 17: Применение байесовских сетей для анализа рисков
#
# Описание:
# Вы хотите оценить риски финансовых операций с помощью байесовской сети.
# Требования:
#
# Используйте данные о финансовых транзакциях (например, Credit Card Fraud Detection).
# Постройте байесовскую сеть, где узлы — это признаки транзакций и вероятность мошенничества.
# Выполните вывод вероятности мошенничества для новых транзакций.
# Оцените точность предсказаний.
# Дополнительно:
#
# Сравните результаты с логистической регрессией.
#
# https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
#
# # 9. Марковские цепи (Markov Chains)
#
# ## Задание 18: Моделирование марковской цепи для временных рядов
#
# Описание:
# Вы хотите смоделировать поведение пользователей на сайте с помощью марковской цепи.
# Требования:
#
# Используйте данные о последовательностях переходов пользователей между страницами сайта.
# Постройте матрицу переходов для марковской цепи.
# Смоделируйте поведение пользователей на несколько шагов вперёд.
# Визуализируйте матрицу переходов и стационарное распределение.
# Дополнительно:
#
# Найдите стационарное распределение с помощью numpy.linalg.eig.
#
#
#
# ## Задание 19: Прогнозирование с помощью марковских цепей
#
# Описание:
# Вы хотите спрогнозировать погоду на основе исторических данных с помощью марковской цепи.
# Требования:
#
# Используйте данные о погоде (например, Seattle Weather Dataset).
# Постройте матрицу переходов для состояний погоды (солнечно, дождливо, облачно).
# Спрогнозируйте погоду на следующие 5 дней.
# Оцените точность прогноза.
# Дополнительно:
#
# Сравните результаты с простой моделью временных рядов (например, ARIMA).
#
# https://www.kaggle.com/datasets/anujvyas/weather-data-seattle-20122015
#
# ## Задание 20: Марковские цепи для анализа последовательностей
#
# Описание:
# Вы хотите проанализировать последовательности покупок клиентов с помощью марковских цепей.
# Требования:
#
# Используйте данные о покупках клиентов (например, Market Basket Analysis Dataset).
# Постройте матрицу переходов для последовательностей покупок.
# Найдите наиболее вероятные последовательности покупок.
# Визуализируйте граф переходов.
# Дополнительно:
#
# Примените алгоритм Viterbi для поиска наиболее вероятной последовательности.
#
# https://www.kaggle.com/datasets/irfanasrullah/market-basket-analysis
#
# # 10. Приближённые байесовские методы
#
# ## Задание 21: Вариационный байесовский вывод
#
# Описание:
# Вы хотите применить вариационный байесовский вывод для логистической регрессии.
# Требования:
#
# Используйте датасет Breast Cancer.
# Реализуйте вариационный байесовский вывод с помощью pymc3 или tensorflow_probability.
# Сравните апостериорные распределения весов с точными методами (например, MCMC).
# Визуализируйте апостериорные распределения.
# Дополнительно:
#
# Оцените качество предсказаний с неопределённостью.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_breast_cancer.html
#
# ## Задание 22: Метод Монте-Карло для байесовского вывода
#
# Описение:
# Вы хотите применить метод Монте-Карло для оценки апостериорных распределений.
# Требования:
#
# Используйте датасет Iris.
# Реализуйте байесовскую логистическую регрессию с неинформативными априорными распределениями.
# Примените MCMC (pymc3.sample) для получения апостериорных распределений.
# Визуализируйте цепи Маркова и апостериорные распределения.
# Дополнительно:
#
# Сравните результаты с вариационным байесовским выводом.
#
# https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html
#
# ## Задание 23: Приближённый байесовский вывод с помощью Stochastic Variational Inference (SVI)
#
# Описание:
# Вы хотите применить SVI для байесовской нейронной сети.
# Требования:
#
# Используйте датасет MNIST.
# Постройте байесовскую нейронную сеть с одним скрытым слоем.
# Примените SVI с помощью tensorflow_probability или pyro.
# Визуализируйте апостериорные распределения весов.
# Дополнительно:
#
# Оцените неопределённость предсказаний модели.
#
# https://www.kaggle.com/datasets/hojjatk/mnist-dataset
#
# ## Задание 24: Применение байесовского бустинга (XGBoost с байесовской оптимизацией)
#
# Описание:
# Вы хотите оптимизировать гиперпараметры XGBoost с помощью байесовской оптимизации.
# Требования:
#
# Используйте датасет House Prices.
# Примените байесовскую оптимизацию для подбора гиперпараметров XGBoost с помощью scikit-optimize или optuna.
# Сравните результаты с случайным поиском и сеткой параметров.
# Визуализируйте процесс оптимизации.
# Дополнительно:
#
# Оцените влияние байесовской оптимизации на качество модели.
#
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
#
# # 11. Комбинированные задания
#
# ## Задание 25: Байесовские сети + Марковские цепи
#
# Описание:
# Вы хотите объединить байесовские сети и марковские цепи для анализа временных последовательностей.
# Требования:
#
# Используйте данные о последовательностях действий пользователей на сайте.
# Постройте динамическую байесовскую сеть, где состояния зависят от предыдущих (марковское свойство).
# Выполните вывод вероятностей последовательностей действий.
# Визуализируйте структуру сети и результаты вывода.
# Дополнительно:
#
# Сравните с простой марковской цепью.
#
#
#
# ## Задание 26: Приближённые байесовские методы для больших данных
#
# Описание:
# Вы хотите применить приближённые байесовские методы для анализа больших данных.
# Требования:
#
# Используйте датасет NYC Taxi Trips.
# Примените Stochastic Variational Inference (SVI) для байесовской линейной регрессии.
# Сравните результаты с полным байесовским выводом на подвыборке данных.
# Оцените масштабируемость метода.
# Дополнительно:
#
# Примените мини-батчи для ускорения обучения.
#
# https://www.kaggle.com/c/nyc-taxi-trip-duration/data

# %% [markdown]
# > практические задания для углублённого изучения байесовских процессов Гаусса, байесовской оптимизации гиперпараметров и применения байесовских методов в глубоком обучении
#
# # 12. Байесовские процессы Гаусса (Gaussian Processes)
#
# ## Задание 27: Регрессия с использованием байесовских процессов Гаусса
#
# Описание:
# Вы хотите применить байесовские процессы Гаусса для задачи регрессии и оценить неопределённость предсказаний.
# Требования:
#
# Используйте датасет Boston Housing.
# Постройте модель байесовского процесса Гаусса с помощью sklearn.gaussian_process.GaussianProcessRegressor.
# Визуализируйте предсказания модели вместе с доверительными интервалами.
# Сравните результаты с линейной регрессией.
# Дополнительно:
#
# Попробуйте разные ядра (например, RBF, Matern) и оцените их влияние на предсказания.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_boston.html
#
# ## Задание 28: Классификация с использованием байесовских процессов Гаусса
#
# Описание:
# Вы хотите применить байесовские процессы Гаусса для задачи бинарной классификации.
# Требования:
#
# Используйте датасет Breast Cancer.
# Постройте модель байесовского процесса Гаусса для классификации с помощью sklearn.gaussian_process.GaussianProcessClassifier.
# Визуализируйте вероятности принадлежности к классам.
# Оцените качество модели с помощью метрик (например, ROC-AUC).
# Дополнительно:
#
# Сравните результаты с логистической регрессией.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_breast_cancer.html
#
# ## Задание 29: Оптимизация гиперпараметров ядра
#
# Описание:
# Вы хотите оптимизировать гиперпараметры ядра для байесовского процесса Гаусса.
# Требования:
#
# Используйте датасет Diabetes.
# Определите пространство гиперпараметров для ядра RBF:
#
# Длина масштаба (length_scale).
# Амплитуда (alpha).
#
# Оптимизируйте гиперпараметры с помощью sklearn.gaussian_process.kernels и scipy.optimize.
# Визуализируйте оптимизированные предсказания.
# Дополнительно:
#
# Используйте байесовскую оптимизацию (scikit-optimize или optuna) для подбора гиперпараметров.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_diabetes.html
#
# # 13. Байесовская оптимизация гиперпараметров
#
# ## Задание 30: Байесовская оптимизация для случайного леса
#
# Описание:
# Вы хотите оптимизировать гиперпараметры модели случайного леса с помощью байесовской оптимизации.
# Требования:
#
# Используйте датасет Wine Quality.
# Определите пространство гиперпараметров:
#
# n_estimators: [50, 500]
# max_depth: [3, 20]
# min_samples_split: [2, 20]
#
# Используйте scikit-optimize или optuna для байесовской оптимизации:
#
# ```
# from skopt import gp_minimize
# from skopt.space import Integer
#
# space = [
#     Integer(50, 500, name='n_estimators'),
#     Integer(3, 20, name='max_depth'),
#     Integer(2, 20, name='min_samples_split')
# ]
#
# def objective(params):
#     model = RandomForestClassifier(
#         n_estimators=params[0],
#         max_depth=params[1],
#         min_samples_split=params[2],
#         random_state=42
#     )
#     score = cross_val_score(model, X, y, cv=5, scoring='accuracy').mean()
#     return -score
#
# result = gp_minimize(objective, space, n_calls=50, random_state=42)
# ```
#
# Визуализируйте процесс оптимизации и обучите финальную модель с лучшими параметрами.
# Дополнительно:
#
# Сравните результаты с оптимизацией через GridSearchCV.
#
# https://www.kaggle.com/datasets/uciml/red-wine-quality-cortez-et-al-2009
#
# ## Задание 31: Байесовская оптимизация для нейронной сети
#
# Описание:
# Вы хотите оптимизировать архитектуру и гиперпараметры нейронной сети с помощью байесовской оптимизации.
# Требования:
#
# Используйте датасет MNIST.
# Определите пространство гиперпараметров:
#
# Количество нейронов в скрытом слое: [32, 512]
# learning_rate: [0.0001, 0.1]
# dropout_rate: [0.0, 0.5]
#
# Используйте optuna для оптимизации:
#
# ```
# import optuna
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Dropout
#
# def objective(trial):
#     n_units = trial.suggest_int('n_units', 32, 512)
#     lr = trial.suggest_float('lr', 1e-4, 1e-1, log=True)
#     dropout_rate = trial.suggest_float('dropout_rate', 0.0, 0.5)
#
#     model = Sequential([
#         Dense(n_units, activation='relu', input_shape=(input_dim,)),
#         Dropout(dropout_rate),
#         Dense(10, activation='softmax')
#     ])
#     model.compile(optimizer=tf.keras.optimizers.Adam(lr), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#     model.fit(X_train, y_train, epochs=10, batch_size=64, validation_data=(X_val, y_val), verbose=0)
#     return model.evaluate(X_val, y_val, verbose=0)[1]
#
# study = optuna.create_study(direction='maximize')
# study.optimize(objective, n_trials=30)
# ```
#
# Визуализируйте важность гиперпараметров.
# Дополнительно:
#
# Добавьте оптимизацию количества слоёв.
#
# https://www.kaggle.com/datasets/hojjatk/mnist-dataset
#
# ## Задание 32: Оптимизация гиперпараметров для XGBoost
#
# Описание:
# Вы хотите оптимизировать гиперпараметры модели XGBoost с помощью байесовской оптимизации.
# Требования:
#
# Используйте датасет House Prices.
# Определите пространство гиперпараметров:
#
# learning_rate: [0.01, 0.3]
# max_depth: [3, 10]
# n_estimators: [50, 500]
# subsample: [0.6, 1.0]
#
# Используйте hyperopt для оптимизации:
#
# ```
# from hyperopt import fmin, tpe, hp, Trials
# from xgboost import XGBRegressor
#
# space = {
#     'learning_rate': hp.loguniform('learning_rate', -2, -0.5),
#     'max_depth': hp.quniform('max_depth', 3, 10, 1),
#     'n_estimators': hp.quniform('n_estimators', 50, 500, 50),
#     'subsample': hp.uniform('subsample', 0.6, 1.0)
# }
#
# def objective(params):
#     model = XGBRegressor(**params)
#     score = cross_val_score(model, X, y, cv=5, scoring='neg_root_mean_squared_error').mean()
#     return -score
#
# trials = Trials()
# best = fmin(objective, space, algo=tpe.suggest, max_evals=50, trials=trials)
# ```
#
# Обучите финальную модель с лучшими параметрами.
# Дополнительно:
#
# Сравните результаты с оптимизацией через Optuna.
#
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
#
# # 14. Применение байесовских методов в глубоком обучении
#
# ## Задание 33: Байесовская нейронная сеть с использованием TensorFlow Probability
#
# Описание:
# Вы хотите построить байесовскую нейронную сеть для классификации изображений.
# Требования:
#
# Используйте датасет CIFAR-10.
# Постройте байесовскую нейронную сеть с одним скрытым слоем с помощью tensorflow_probability:
#
# ```
# import tensorflow_probability as tfp
#
# model = tf.keras.Sequential([
#     tfp.layers.DenseVariational(128, activation='relu', input_shape=(32, 32, 3)),
#     tf.keras.layers.Flatten(),
#     tfp.layers.DenseVariational(10, activation='softmax')
# ])
# model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.001),
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy'])
# ```
#
# Обучите модель и визуализируйте апостериорные распределения весов.
# Оцените неопределённость предсказаний.
# Дополнительно:
#
# Сравните с обычной нейронной сетью по качеству предсказаний.
#
# https://www.kaggle.com/datasets/shaunthesheep/cifar10
#
# ## Задание 34: Применение байесовских методов для сегментации изображений
#
# Описание:
# Вы хотите применить байесовские методы для сегментации медицинских изображений.
# Требования:
#
# Используйте датасет Brain Tumor Segmentation.
# Постройте байесовскую U-Net сеть с использованием tensorflow_probability.
# Визуализируйте предсказания и неопределённость сегментации.
# Оцените качество модели с помощью метрик (например, Dice score).
# Дополнительно:
#
# Сравните результаты с обычной U-Net.
#
# https://www.kaggle.com/datasets/navoneel/brain-mri-images-for-brain-tumor-detection
#
# ## Задание 35: Байесовская оптимизация архитектуры нейронной сети
#
# Описание:
# Вы хотите оптимизировать архитектуру нейронной сети для задачи регрессии.
# Требования:
#
# Используйте датасет California Housing.
# Определите пространство гиперпараметров:
#
# Количество слоёв: [1, 4]
# Количество нейронов в слое: [32, 512]
# learning_rate: [0.0001, 0.1]
#
# Используйте optuna для оптимизации архитектуры:
#
# ```
# def objective(trial):
#     n_layers = trial.suggest_int('n_layers', 1, 4)
#     n_units = trial.suggest_int('n_units', 32, 512)
#     lr = trial.suggest_float('lr', 1e-4, 1e-1, log=True)
#
#     model = Sequential()
#     model.add(Flatten(input_shape=(8,)))
#     for _ in range(n_layers):
#         model.add(Dense(n_units, activation='relu'))
#     model.add(Dense(1))
#
#     model.compile(optimizer=Adam(lr), loss='mse')
#     model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_val, y_val), verbose=0)
#     return model.evaluate(X_val, y_val, verbose=0)[0]
#
# study = optuna.create_study(direction='minimize')
# study.optimize(objective, n_trials=30)
# ```
#
# Обучите финальную модель с лучшими параметрами.
# Дополнительно:
#
# Добавьте оптимизацию dropout_rate.
#
# https://www.kaggle.com/datasets/camnugent/california-housing-prices

# %% [markdown]
# добавить задания по другим аспектам (например, байесовские методы для обработки естественного языка, применение байесовских процессов Гаусса в временных рядах, байесовские методы для анализа графов)
