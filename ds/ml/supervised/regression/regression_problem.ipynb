# %% [markdown]
# # Regression Problem (Постановка задачи регрессии)

# %% [markdown]
# ### Задание 1: Формулировка задачи регрессии
#
# Описание:
# Вы аналитик в компании, которая занимается прогнозированием спроса на продукты. Вам нужно сформулировать задачу регрессии на основе предоставленных данных.
# Требования:
#
# Используйте датасет Store Sales.
# Определите:
#
# Целевую переменную (например, объём продаж).
# Признаки (например, дата, промоакции, праздники).
#
# Напишите формальную постановку задачи регрессии:
#
# Какие переменные влияют на целевую?
# Какие предположения вы делаете о данных?
#
# Визуализируйте зависимость целевой переменной от 1–2 ключевых признаков (sns.scatterplot, sns.lineplot).
# Дополнительно:
#
# Проверьте данные на наличие выбросов и пропусков.

# %%
# https://www.kaggle.com/c/store-sales-time-series-forecasting/data

# %% [markdown]
# ### Задание 2: Анализ признаков для регрессии
#
# Описание:
# Вы работаете с датасетом о ценах на недвижимость и хотите понять, какие признаки могут влиять на стоимость.
# Требования:
#
# Используйте датасет Boston Housing или California Housing.
# Проведите анализ:
#
# Корреляция между признаками и целевой переменной (df.corr()).
# Визуализация корреляционной матрицы (sns.heatmap).
#
# Выберите 3 наиболее значимых признака и обоснуйте свой выбор.
# Дополнительно:
#
# Постройте парные графики (sns.pairplot) для выбранных признаков.

# %%
# https://www.kaggle.com/datasets/vikrishnan/boston-house-prices
# https://www.kaggle.com/datasets/camnugent/california-housing-prices

# %% [markdown]
# ## Linear Regression (Линейная регрессия)

# %% [markdown]
# ### Задание 3: Построение линейной регрессии
#
# Описание:
# Вы хотите предсказать цену автомобиля на основе его характеристик.
# Требования:
#
# Используйте датасет Car Price Prediction.
# Постройте модель линейной регрессии (sklearn.linear_model.LinearRegression).
# Визуализируйте:
#
# Линию регрессии для зависимости цены от одного из признаков (sns.regplot).
# График остатков (sns.residplot).
#
# Интерпретируйте коэффициенты модели.
# Дополнительно:
#
# Проверьте предположения линейной регрессии (нормальность остатков, гомоскедастичность).

# %%
# https://www.kaggle.com/datasets/hellbuoy/car-price-prediction

# %% [markdown]
# ### Задание 4: Множественная линейная регрессия
#
# Описание:
# Вы анализируете датасет с информацией о студентах и хотите предсказать их успеваемость.
# Требования:
#
# Используйте датасет Students Performance.
# Постройте модель множественной линейной регрессии.
# Оцените значимость признаков с помощью:
#
# p-values (statsmodels.api.OLS).
# Коэффициентов стандартизированной регрессии.
#
# Визуализируйте зависимость предсказаний от реальных значений (sns.scatterplot).
# Дополнительно:
#
# Удалите незначимые признаки и переобучите модель.

# %%
# https://www.kaggle.com/datasets/spscientist/students-performance-in-exams

# %% [markdown]
# ## Gradient Descent (Градиентный спуск)

# %% [markdown]
# ### Задание 5: Реализация градиентного спуска
#
# Описание:
# Вы хотите вручную реализовать градиентный спуск для линейной регрессии.
# Требования:
#
# Сгенерируйте синтетические данные (sklearn.datasets.make_regression).
# Реализуйте градиентный спуск:
#
# Функция потерь: MSE.
# Обновление весов: $w = w - \alpha \cdot \nabla J(w)$.
#
# Визуализируйте:
#
# Кривую обучения (изменение функции потерь по итерациям).
# Сравнение с решением sklearn.linear_model.LinearRegression.
#
# Дополнительно:
#
# Добавьте регуляризацию (L2) и сравните результаты.

# %% [markdown]
# ### Задание 6: Сравнение методов оптимизации
#
# Описание:
# Вы хотите сравнить скорость сходимости разных методов градиентного спуска.
# Требования:
#
# Используйте датасет Diabetes.
# Реализуйте и сравните:
#
# Batch Gradient Descent.
# Stochastic Gradient Descent (SGD).
# Mini-batch Gradient Descent.
#
# Визуализируйте кривые обучения для каждого метода.
# Дополнительно:
#
# Добавьте momentum и сравните скорость сходимости.

# %%
# https://www.kaggle.com/datasets/uciml/diabetes-dataset

# %% [markdown]
# ## Overfitting and Underfitting (Переобучение и недообучение)

# %% [markdown]
# ### Задание 7: Диагностика переобучения
#
# Описание:
# Вы обучаете модель на данных о ценах на недвижимость и подозреваете переобучение.
# Требования:
#
# Используйте датасет Ames Housing.
# Постройте модели:
#
# Линейная регрессия.
# Полиномиальная регрессия (степень 3 и 10).
#
# Визуализируйте:
#
# Кривые обучения (sklearn.model_selection.learning_curve).
# Графики предсказаний на обучающей и тестовой выборках.
#
# Определите, какая модель переобучена/недообучена.
# Дополнительно:
#
# Примените кросс-валидацию для оценки стабильности моделей.

# %%
# https://www.kaggle.com/datasets/prevek18/ameshousing

# %% [markdown]
# ### Задание 8: Борьба с переобучением
#
# Описание:
# Вы хотите улучшить модель, склонную к переобучению.
# Требования:
#
# Используйте датасет Bike Sharing Demand.
# Примените техники для борьбы с переобучением:
#
# Регуляризация (L1, L2).
# Уменьшение размерности (PCA).
# Кросс-валидация.
#
# Сравните метрики (RMSE, R²) до и после применения техник.
# Дополнительно:
#
# Постройте график важности признаков после регуляризации.

# %%
# https://www.kaggle.com/datasets/c/clane-bike-sharing-demand

# %% [markdown]
# ## Regularization (Регуляризация)

# %% [markdown]
# ### Задание 9: Сравнение L1 и L2 регуляризации
#
# Описание:
# Вы хотите сравнить влияние L1 и L2 регуляризации на модель.
# Требования:
#
# Используйте датасет Hitters.
# Постройте модели:
#
# Ridge Regression (L2).
# Lasso Regression (L1).
#
# Визуализируйте:
#
# Зависимость коэффициентов от параметра регуляризации (np.logspace).
# Сравнение метрик (MSE) на тестовой выборке.
#
# Определите, какая регуляризация лучше подходит для этого датасета.
# Дополнительно:
#
# Примените Elastic Net и сравните результаты.

# %%
# https://www.kaggle.com/datasets/jeffreytwong/baseball-hitters-dataset

# %% [markdown]
# ### Задание 10: Подбор параметра регуляризации
#
# Описание:
# Вы хотите оптимизировать параметр регуляризации для модели Ridge.
# Требования:
#
# Используйте датасет Wine Quality.
# Подберите оптимальный параметр α\alphaα с помощью:
#
# Grid Search (sklearn.model_selection.GridSearchCV).
# Random Search.
#
# Визуализируйте зависимость метрик от α\alphaα.
# Дополнительно:
#
# Постройте график важности признаков для оптимальной модели.

# %%
# https://www.kaggle.com/datasets/uciml/red-wine-quality-cortez-et-al-2009

# %% [markdown]
# ## Quality Metrics (Метрики качества)

# %% [markdown]
# ### Задание 11: Сравнение метрик регрессии
#
# Описание:
# Вы хотите оценить качество модели регрессии с помощью разных метрик.
# Требования:
#
# Используйте датасет House Prices.
# Постройте модель (например, RandomForestRegressor).
# Рассчитайте метрики:
#
# MAE, MSE, RMSE, R².
# MAPE (Mean Absolute Percentage Error).
#
# Визуализируйте:
#
# График остатков.
# Сравнение предсказаний и реальных значений.
#
# Дополнительно:
#
# Постройте график распределения остатков (sns.distplot).

# %%
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data

# %% [markdown]
# ### Задание 12: Анализ остатков
#
# Описание:
# Вы хотите проверить, соответствуют ли остатки модели предположениям линейной регрессии.
# Требования:
#
# Используйте датасет Insurance.
# Постройте модель линейной регрессии.
# Проанализируйте остатки:
#
# Нормальность распределения (Q-Q plot, stats.probplot).
# Гомоскедастичность (sns.residplot).
#
# Сделайте выводы о применимости линейной регрессии.
# Дополнительно:
#
# Примените преобразование Box-Cox к целевой переменной и повторите анализ.

# %%
# https://www.kaggle.com/datasets/mirichoi0218/insurance

# %% [markdown]
# ## Alternative Linear Regression Problem Formulation (Альтернативные формулировки задачи регрессии)

# %% [markdown]
# ### Задание 13: Регрессия с регулярными ограничениями
#
# Описание:
# Вы хотите построить модель регрессии с ограничениями на коэффициенты.
# Требования:
#
# Используйте датасет Concrete Compressive Strength.
# Постройте модель с ограничениями:
#
# Все коэффициенты должны быть неотрицательными (sklearn.linear_model.LinearRegression с positive=True).
#
# Сравните с обычной линейной регрессией по метрикам (RMSE, R²).
# Дополнительно:
#
# Визуализируйте коэффициенты обеих моделей.

# %%
# https://www.kaggle.com/datasets/elvis23/concrete-compressive-strength

# %% [markdown]
# ### Задание 14: Робастная регрессия
#
# Описание:
# Вы работаете с данными, содержащими выбросы, и хотите построить устойчивую модель.
# Требования:
#
# Используйте датасет Diamond Prices.
# Постройте модели:
#
# Обычная линейная регрессия.
# Робастная регрессия (sklearn.linear_model.HuberRegressor).
#
# Сравните модели по метрикам и визуализируйте предсказания.
# Дополнительно:
#
# Добавьте выбросы в данные и повторите сравнение.

# %%
# https://www.kaggle.com/datasets/shivam2503/diamonds

# %% [markdown]
# ### Задание 15: Квантильная регрессия
#
# Описание:
# Вы хотите предсказать не только среднее значение, но и квантили распределения.
# Требования:
#
# Используйте датасет NYC Taxi Trip Duration.
# Постройте модель квантильной регрессии (statsmodels.regression.quantile_regression.QuantReg).
# Визуализируйте предсказания для разных квантилей (0.1, 0.5, 0.9).
# Дополнительно:
#
# Сравните с обычной линейной регрессией по покрытию реальных значений.

# %%
# https://www.kaggle.com/c/nyc-taxi-trip-duration/data
