# %% [markdown]
# # Байесовская регрессия (Bayesian Regression)

# %% [markdown]
# ## Задание 16: Байесовская линейная регрессия
#
# Описание:
# Вы хотите оценить неопределённость предсказаний модели с помощью байесовской регрессии.
# Требования:
#
# Используйте датасет Boston Housing.
# Постройте модель байесовской регрессии с помощью:
#
# pymc3 или stan (для полноценного байесовского подхода).
# sklearn.linear_model.BayesianRidge (для упрощённого подхода).
#
# Визуализируйте:
#
# Распределение коэффициентов (постпредиктивное распределение).
# Доверительные интервалы для предсказаний.
#
# Сравните результаты с классической линейной регрессией.
# Дополнительно:
#
# Постройте график сходимости цепей Маркова (trace plot) для pymc3.
#
# https://www.kaggle.com/datasets/vikrishnan/boston-house-prices
#
# ## Задание 17: Байесовская регрессия с приорами
#
# Описание:
# Вы хотите задать информативные приоры для коэффициентов регрессии на основе экспертных знаний.
# Требования:
#
# Используйте датасет Wine Quality.
# Задайте приоры для коэффициентов (например, нормальное распределение с определённым средним и дисперсией).
# Постройте модель с помощью pymc3 или stan.
# Сравните результаты с неинформативными приорами.
# Дополнительно:
#
# Проанализируйте, как выбор приоров влияет на ширину доверительных интервалов.
#
# https://www.kaggle.com/datasets/uciml/red-wine-quality-cortez-et-al-2009
#
# ## Задание 18: Байесовская логистическая регрессия
#
# Описание:
# Вы хотите классифицировать отзывы на положительные и отрицательные с учётом неопределённости.
# Требования:
#
# Используйте датасет IMDB Reviews.
# Преобразуйте текстовые данные в числовые признаки (например, TF-IDF).
# Постройте байесовскую логистическую регрессию с помощью pymc3.
# Визуализируйте распределение вероятностей для предсказаний.
# Дополнительно:
#
# Сравните результаты с классической логистической регрессией по метрикам (AUC-ROC, F1-score).
#
# https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
#
# # 9. Регрессия со смешанными эффектами (Mixed-Effects Models)
#
# ## Задание 19: Линейная регрессия со смешанными эффектами
#
# Описание:
# Вы анализируете данные о росте растений в разных условиях и хотите учесть влияние случайных эффектов (например, индивидуальных особенностей растений).
# Требования:
#
# Используйте датасет Plant Growth или Sleep Study.
# Постройте модель со смешанными эффектами с помощью:
#
# statsmodels.regression.mixed_linear_model.MixedLM.
# lme4 (в R через rpy2, если работаете в Python).
#
# Интерпретируйте фиксированные и случайные эффекты.
# Сравните модель со смешанными эффектами с обычной линейной регрессией.
# Дополнительно:
#
# Визуализируйте случайные эффекты для разных групп.
#
# https://www.kaggle.com/datasets/abhishek14398/plant-growth-data
#
# https://www.kaggle.com/datasets/abhishek14398/sleep-study-data
#
# ## Задание 20: Анализ продольных данных
#
# Описание:
# Вы анализируете данные о весе пациентов в разные моменты времени и хотите учесть индивидуальные траектории.
# Требования:
#
# Используйте датасет Weight Loss Study.
# Постройте модель со смешанными эффектами, где:
#
# Фиксированные эффекты: время, диета.
# Случайные эффекты: индивидуальные особенности пациентов.
#
# Визуализируйте индивидуальные траектории пациентов.
# Дополнительно:
#
# Проверьте значимость случайных эффектов с помощью логарифмического отношения правдоподобия (Likelihood Ratio Test).
#
# https://www.kaggle.com/datasets/abhishek14398/weight-loss-study-data
#
# ## Задание 21: Смешанные эффекты в экспериментальных данных
#
# Описание:
# Вы анализируете данные эксперимента, где одни и те же субъекты проходили несколько тестов.
# Требования:
#
# Используйте датасет Repeated Measures ANOVA.
# Постройте модель со смешанными эффектами, где:
#
# Фиксированные эффекты: условия эксперимента.
# Случайные эффекты: индивидуальные особенности субъектов.
#
# Сравните результаты с обычным ANOVA.
# Дополнительно:
#
# Постройте графики предсказаний для каждого субъекта.
#
# https://www.kaggle.com/datasets/abhishek14398/repeated-measures-anova-data
#
# # 10. Комбинированные задания
#
# ## Задание 22: Байесовская регрессия со смешанными эффектами
#
# Описание:
# Вы хотите объединить байесовский подход и смешанные эффекты для анализа данных о продажах в разных магазинах.
# Требования:
#
# Используйте датасет Store Sales.
# Постройте байесовскую модель со смешанными эффектами с помощью pymc3 или brms (в R).
# Визуализируйте:
#
# Распределение фиксированных и случайных эффектов.
# Доверительные интервалы для предсказаний по каждому магазину.
#
# Дополнительно:
#
# Сравните с классической регрессией со смешанными эффектами по метрикам (RMSE, WAIC).
#
# https://www.kaggle.com/c/store-sales-time-series-forecasting/data
#
# ## Задание 23: Сравнение подходов на реальных данных
#
# Описание:
# Вы хотите сравнить классическую регрессию, байесовскую регрессию и регрессию со смешанными эффектами на одном датасете.
# Требования:
#
# Используйте датасет Student Performance.
# Постройте три модели:
#
# Классическая линейная регрессия.
# Байесовская регрессия (pymc3).
# Регрессия со смешанными эффектами (statsmodels).
#
# Сравните модели по:
#
# Качеству предсказаний (RMSE, R²).
# Интерпретируемости.
# Учёту неопределённости.
#
# Дополнительно:
#
# Визуализируйте предсказания всех трёх моделей на одном графике.
#
# https://www.kaggle.com/datasets/spscientist/students-performance-in-exams

# %% [markdown]
# # 11. Непараметрическая регрессия (Nonparametric Regression)
#
# ## Задание 24: Ядерная регрессия (Kernel Regression)
#
# Описание:
# Вы хотите предсказать зависимость без предположений о её функциональной форме, используя ядерную регрессию.
# Требования:
#
# Используйте датасет Boston Housing или сгенерируйте синтетические данные с нелинейной зависимостью.
# Реализуйте ядерную регрессию с гауссовым ядром:
#
# Используйте sklearn.kernel_ridge.KernelRidge или реализуйте вручную.
#
# Визуализируйте:
#
# Кривую регрессии на фоне исходных данных.
# Влияние ширины ядра (bandwidth) на сглаживание.
#
# Сравните результаты с полиномиальной регрессией.
# Дополнительно:
#
# Постройте график остатков для оценки качества подгонки.
#
# https://www.kaggle.com/datasets/vikrishnan/boston-house-prices
#
# ## Задание 25: Локально взвешенное сглаживание (LOESS)
#
# Описание:
# Вы анализируете данные с сильной нелинейностью и хотите применить локальное сглаживание.
# Требования:
#
# Используйте датасет Diamonds или Air Quality.
# Примените LOESS с помощью statsmodels.nonparametric.smoothers_lowess.lowess.
# Визуализируйте:
#
# Локальные тренды для разных подмножеств данных.
# Сравнение с глобальной полиномиальной регрессией.
#
# Оцените, как изменяется качество предсказания при изменении параметра сглаживания.
# Дополнительно:
#
# Реализуйте LOESS вручную для одного признака.
#
# https://www.kaggle.com/datasets/shivam2503/diamonds
#
# https://www.kaggle.com/datasets/uciml/air-quality
#
# ## Задание 26: Сплайн-регрессия
#
# Описание:
# Вы хотите использовать сплайны для моделирования сложных зависимостей.
# Требования:
#
# Используйте датасет Wage Data.
# Постройте модели:
#
# Линейная регрессия.
# Сплайн-регрессия (sklearn.preprocessing.SplineTransformer или statsmodels.regression.splines).
#
# Визуализируйте:
#
# Сплайн-базисы.
# Кривые регрессии для обеих моделей.
#
# Сравните модели по метрикам (RMSE, R²).
# Дополнительно:
#
# Поэкспериментируйте с количеством узлов сплайна.
#
# https://www.kaggle.com/datasets/uciml/wage-data
#
# # 12. Регрессия с квантилями (Quantile Regression)
#
# ## Задание 27: Квантильная регрессия для анализа распределения
#
# Описание:
# Вы хотите предсказать не только среднее значение, но и квантили распределения целевой переменной.
# Требования:
#
# Используйте датасет NYC Taxi Trip Duration.
# Постройте квантильную регрессию для квантилей 0.1, 0.5, 0.9 с помощью:
#
# statsmodels.regression.quantile_regression.QuantReg.
#
# Визуализируйте:
#
# Предсказанные квантили на фоне исходных данных.
# Интервалы предсказаний (например, 10–90%).
#
# Сравните с обычной линейной регрессией по покрытию реальных значений.
# Дополнительно:
#
# Постройте график остатков для каждого квантиля.
#
# https://www.kaggle.com/c/nyc-taxi-trip-duration/data
#
# ## Задание 28: Применение квантильной регрессии для анализа выбросов
#
# Описание:
# Вы хотите выявить выбросы в данных о продажах недвижимости.
# Требования:
#
# Используйте датасет Ames Housing.
# Постройте квантильную регрессию для квантилей 0.05 и 0.95.
# Визуализируйте:
#
# Данные, лежащие за пределами предсказанных квантилей, как потенциальные выбросы.
#
# Сравните результаты с методами обнаружения выбросов (например, Z-score, IQR).
# Дополнительно:
#
# Постройте модель для предсказания медианы и сравните с квантильной регрессией.
#
# https://www.kaggle.com/datasets/prevek18/ameshousing
#
# ## Задание 29: Квантильная регрессия для временных рядов
#
# Описание:
# Вы анализируете временные ряды и хотите предсказать квантили для оценки рисков.
# Требования:
#
# Используйте датасет Stock Prices или Bitcoin Historical Data.
# Постройте квантильную регрессию для предсказания квантилей 0.05, 0.5, 0.95.
# Визуализируйте:
#
# Предсказанные квантили на графике временного ряда.
# Зоны риска (например, 5–95% интервал).
#
# Оцените, как часто реальные значения выходят за пределы предсказанных интервалов.
# Дополнительно:
#
# Сравните с моделью ARIMA по качеству предсказания квантилей.
#
# https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs
#
# https://www.kaggle.com/datasets/mczielinski/bitcoin-historical-data
#
# # 13. Регрессия на графах (Graph-Based Regression)
#
# ## Задание 30: Регрессия на графах с использованием Graph Neural Networks (GNN)
#
# Описание:
# Вы хотите предсказать свойства узлов в социальном графе, используя информацию о его структуре.
# Требования:
#
# Используйте датасет Cora или CiteSeer.
# Постройте модель регрессии на графах с помощью:
#
# PyTorch Geometric или DGL (Deep Graph Library).
# Простая модель: Graph Convolutional Network (GCN) для регрессии.
#
# Визуализируйте:
#
# Структуру графа (networkx).
# Предсказания для узлов графа.
#
# Оцените качество модели с помощью метрик (RMSE, MAE).
# Дополнительно:
#
# Сравните с базовой линейной регрессией, игнорирующей структуру графа.
#
# https://linqs.soe.ucsc.edu/data
#
# ## Задание 31: Регрессия с использованием Graph Laplacian
#
# Описание:
# Вы хотите использовать лапласиан графа для сглаживания предсказаний.
# Требования:
#
# Используйте датасет Zachary’s Karate Club или сгенерируйте синтетический граф.
# Постройте модель регрессии с регуляризацией на основе лапласиана:
#
# min⁡∥y−Xβ∥2+λβTLβ\min \|y - X\beta\|^2 + \lambda \beta^T L \betamin∥y−Xβ∥2+λβTLβ, где LLL — лапласиан графа.
#
# Визуализируйте:
#
# Предсказания для узлов графа.
# Влияние параметра λ\lambdaλ на гладкость предсказаний.
#
# Сравните с обычной линейной регрессией.
# Дополнительно:
#
# Реализуйте метод вручную с использованием numpy и scipy.
#
# https://networkx.org/documentation/stable/auto_examples/graph/plot_karate_club.html
#
# ## Задание 32: Применение GraphSAGE для регрессии
#
# Описание:
# Вы хотите использовать GraphSAGE для предсказания числовых характеристик узлов в большом графе.
# Требования:
#
# Используйте датасет Reddit или ogbn-products.
# Постройте модель GraphSAGE для регрессии с помощью PyTorch Geometric.
# Визуализируйте:
#
# Предсказания для узлов с высокой и низкой степенью.
#
# Оцените качество модели и сравните со стандартными подходами (например, линейная регрессия на признаках узлов).
# Дополнительно:
#
# Проанализируйте, как качество предсказаний зависит от глубины агрегации соседей.
#
# https://snap.stanford.edu/data/reddit.html
#
# https://ogb.stanford.edu/docs/nodeprop/#ogbn-products

# %% [markdown]
# # 14. Функциональная регрессия (Functional Regression)
#
# ## Задание 33: Регрессия с функциональными признаками
#
# Описание:
# Вы анализируете данные, где каждый объект представлен функцией (например, временной ряд, спектр, траектория). Вам нужно предсказать числовую целевую переменную на основе этих функций.
# Требования:
#
# Используйте датасет Tecator (спектры поглощения мяса) или Handwriting (траектории письма).
# Преобразуйте функциональные данные в признаки:
#
# Коэффициенты разложения в базис (например, Фурье, вейвлеты).
# Статистики функций (среднее, дисперсия, производные).
#
# Постройте модель регрессии (например, sklearn.linear_model.Ridge) на полученных признаках.
# Визуализируйте:
#
# Исходные функции.
# Важность полученных признаков.
#
# Дополнительно:
#
# Используйте scipy.fft для разложения в ряд Фурье.
#
# https://www.kaggle.com/datasets/uciml/tecator
#
# https://www.kaggle.com/datasets/irfanasrullah/handwriting-recognition
#
# ## Задание 34: Функциональная PCA и регрессия
#
# Описание:
# Вы хотите уменьшить размерность функциональных данных с помощью функционального PCA и построить регрессию на главных компонентах.
# Требования:
#
# Используйте датасет Canadian Weather (ежедневные температуры).
# Примените функциональный PCA (skfda.preprocessing.dim_reduction.FPCA или fdapace в R).
# Постройте модель регрессии на главных компонентах.
# Визуализируйте:
#
# Главные компоненты как функции.
# Вклад главных компонент в предсказание.
#
# Дополнительно:
#
# Сравните с обычным PCA на дискретных значениях функций.
#
# https://www.kaggle.com/datasets/selfishgene/canadian-weather
#
# ## Задание 35: Регрессия с использованием функциональных базисов
#
# Описание:
# Вы хотите использовать базисные функции (например, B-сплайны) для представления функциональных данных и построения регрессии.
# Требования:
#
# Используйте датасет Phoneme (акустические сигналы).
# Представьте функции в базисе B-сплайнов (scipy.interpolate.BSpline).
# Постройте модель регрессии на коэффициентах сплайнов.
# Визуализируйте:
#
# Аппроксимацию функций сплайнами.
# Предсказания модели.
#
# Дополнительно:
#
# Поэкспериментируйте с количеством узлов сплайнов.
#
# https://www.kaggle.com/datasets/uciml/phoneme
#
# # 15. Регрессия с интервальными данными (Interval Regression)
#
# ## Задание 36: Регрессия с интервальными признаками
#
# Описание:
# Вы анализируете данные, где признаки представлены интервалами (например, диапазон цен, возрастные группы). Вам нужно предсказать целевую переменную на основе таких данных.
# Требования:
#
# Используйте датасет Interval-Valued Data или сгенерируйте синтетические интервальные данные.
# Преобразуйте интервальные признаки в числовые:
#
# Центр и радиус интервала.
# Минимум, максимум, среднее.
#
# Постройте модель регрессии (например, sklearn.ensemble.RandomForestRegressor).
# Визуализируйте:
#
# Распределение интервальных признаков.
# Важность признаков.
#
# Дополнительно:
#
# Реализуйте собственную метрику для оценки качества предсказаний на интервальных данных.
#
# https://archive.ics.uci.edu/ml/datasets.php
#
# ## Задание 37: Регрессия с интервальной целевой переменной
#
# Описание:
# Вы хотите предсказать не точечное значение, а интервал (например, диапазон цен на недвижимость).
# Требования:
#
# Используйте датасет House Prices и преобразуйте целевую переменную в интервалы (например, ±10% от реальной цены).
# Постройте модель для предсказания интервалов:
#
# Две отдельные модели для нижней и верхней границ.
# Модель квантильной регрессии для 0.05 и 0.95 квантилей.
#
# Визуализируйте:
#
# Предсказанные интервалы на фоне реальных значений.
# Долю реальных значений, попадающих в предсказанные интервалы.
#
# Дополнительно:
#
# Оцените качество предсказаний с помощью метрики PICP (Prediction Interval Coverage Probability).
#
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
#
# ## Задание 38: Регрессия с интервальными признаками и целевой переменной
#
# Описание:
# Вы работаете с данными, где и признаки, и целевая переменная представлены интервалами.
# Требования:
#
# Используйте датасет Interval Data или сгенерируйте синтетические данные.
# Постройте модель для предсказания интервальной целевой переменной:
#
# Используйте библиотеку scikit-fuzzy или реализуйте собственную модель.
#
# Визуализируйте:
#
# Предсказанные интервалы и их покрытие реальных значений.
#
# Сравните с моделями, игнорирующими интервальную природу данных.
# Дополнительно:
#
# Реализуйте метрику MPIW (Mean Prediction Interval Width) для оценки ширины интервалов.
#
# https://archive.ics.uci.edu/ml/datasets/Interval+Data
#
# # 16. Причинная регрессия (Causal Regression)
#
# ## Задание 39: Оценка причинно-следственных эффектов с помощью регрессии
#
# Описание:
# Вы хотите оценить причинный эффект вмешательства (например, влияние рекламной кампании на продажи) с учётом конфундирующих переменных.
# Требования:
#
# Используйте датасет Causal Inference Datasets или Lalonde.
# Постройте модели для оценки причинного эффекта:
#
# Линейная регрессия с контролем конфундеров.
# Propensity Score Matching (sklearn.neighbors.NearestNeighbors).
# Double Machine Learning (EconML).
#
# Визуализируйте:
#
# Распределение пропенсити-скора.
# Оценки причинного эффекта для разных групп.
#
# Интерпретируйте результаты: значим ли эффект?
# Дополнительно:
#
# Примените метод Inverse Probability Weighting (IPW).
#
# https://github.com/AMoreau/CausalML_Datasets
#
# https://users.nber.org/~rdehejia/data/nswre74_control.txt
#
# ## Задание 40: Инструментальные переменные (IV Regression)
#
# Описание:
# Вы хотите оценить причинный эффект, когда есть ненаблюдаемые конфундеры, используя инструментальные переменные.
# Требования:
#
# Используйте датасет Angrist & Lavy (1999) или Card (1993).
# Постройте модель инструментальных переменных:
#
# Используйте statsmodels.regression.linear_model.IV2SLS.
#
# Визуализируйте:
#
# Зависимость между инструментом и обработкой.
# Оценки причинного эффекта.
#
# Проверьте валидность инструмента (релевантность и эксклюзивность).
# Дополнительно:
#
# Сравните результаты с OLS-регрессией.
#
# https://www.nber.org/papers/w6032
#
# https://davidcard.berkeley.edu/data_sets.html
#
# ## Задание 41: Разрывная регрессия (Regression Discontinuity Design)
#
# Описание:
# Вы хотите оценить причинный эффект на основе порогового правила назначения обработки.
# Требования:
#
# Используйте датасет Regression Discontinuity Example или сгенерируйте синтетические данные.
# Постройте модель разрывной регрессии:
#
# Локальная линейная регрессия около порога.
#
# Визуализируйте:
#
# Разрыв в целевой переменной на пороге.
# Доверительные интервалы для оценки эффекта.
#
# Оцените значимость эффекта.
# Дополнительно:
#
# Примените непараметрическую оценку разрыва.
#
# https://www.openicpsr.org/openicpsr/project/100321/version/V1/view
#
# ## Задание 42: Причинные леса (Causal Forests)
#
# Описание:
# Вы хотите оценить гетерогенные причинные эффекты с помощью случайных лесов.
# Требования:
#
# Используйте датасет ACIC 2016 или IHDP.
# Постройте модель причинных лесов с помощью:
#
# EconML (CausalForestDML).
#
# Визуализируйте:
#
# Распределение индивидуальных причинных эффектов.
# Важность признаков для оценки эффекта.
#
# Сравните с линейной регрессией.
# Дополнительно:
#
# Оцените ATE (Average Treatment Effect) и CATE (Conditional Average Treatment Effect).
#
# https://www.synapse.org/#!Synapse:syn4954343
#
# https://github.com/AMoreau/CausalML_Datasets

# %% [markdown]
# добавить задания по другим аспектам (например, регрессия с цензурированными данными, регрессия для данных с шумом в признаках, регрессия с учетом пространственной автокорреляции)
