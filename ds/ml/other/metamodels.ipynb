# %%
# !pip install numpy pandas scikit-learn matplotlib catboost
# !pip install kagglehub[pandas-datasets]
# !pip install kaggle

# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import matplotlib.pyplot as plt

from catboost import Pool, CatBoost

from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.preprocessing import OneHotEncoder, StandardScaler, Normalizer
from sklearn.model_selection import train_test_split, StratifiedKFold

from sklearn.metrics import roc_auc_score

pd.options.mode.chained_assignment = None

import kagglehub
from kagglehub import KaggleDatasetAdapter

# %%
path = kagglehub.dataset_download("yasserh/titanic-dataset")

print("Path to dataset files:", path)
import os

dataset_dir = "/kaggle/input/titanic-dataset"
print("Содержимое папки с данными:")
print(os.listdir(dataset_dir))

csv_path = "/kaggle/input/titanic-dataset/Titanic-Dataset.csv"
# Out:
# Path to dataset files: /kaggle/input/titanic-dataset
# Содержимое папки с данными:
# ['Titanic-Dataset.csv']

# %%
df = pd.read_csv(csv_path)
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
TO_DROP = ['PassengerId', 'Name', 'Cabin', 'Ticket']
CATEGORICAL = ['Sex', 'Embarked']
NUMERICAL = ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
TARGET = 'Survived'

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
X = df.drop(columns=TO_DROP + [TARGET])
y = df[TARGET]

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, shuffle=True, test_size=0.2, random_state=21)

X_train.shape, X_test.shape
# Out:
# ((712, 7), (179, 7))
