# %% [markdown]
# # Первичный анализ геопространственных данных

# %% [markdown]
# ### Задание 4: Визуализация геоданных на карте
#
# Описание:
# Вы анализируете датасет с координатами преступлений в городе и хотите визуализировать их распределение.
# Требования:
#
# Используйте датасет San Francisco Crime Dataset или Chicago Crimes.
# Постройте интерактивную карту с помощью:
#
# folium (для статической карты).
# plotly.express.scatter_geo (для интерактивной карты).
#
# Визуализируйте:
#
# Распределение преступлений по районам.
# Heatmap плотности преступлений (folium.plugins.HeatMap).
#
# Проанализируйте, в каких районах наибольшая концентрация преступлений.
# Дополнительно:
#
# Добавьте фильтры по типу преступления и временному периоду.

# %%
# https://www.kaggle.com/datasets/abhishek14398/sf-crime-dataset
# https://www.kaggle.com/datasets/currie32/crimes-in-chicago

# %% [markdown]
# ### Задание 5: Кластеризация геоданных
#
# Описание:
# Вы хотите выявить "горячие точки" преступности с помощью кластеризации.
# Требования:
#
# Используйте тот же датасет преступлений.
# Примените кластеризацию:
#
# DBSCAN (sklearn.cluster.DBSCAN) для выявления плотных кластеров.
# K-Means (sklearn.cluster.KMeans) для разделения на заданное число кластеров.
#
# Визуализируйте кластеры на карте (folium или plotly).
# Сравните результаты DBSCAN и K-Means: какой метод лучше подходит для геоданных?
# Дополнительно:
#
# Постройте график Silhouette Score для оценки качества кластеризации.

# %% [markdown]
# ### Задание 6: Анализ временных и пространственных трендов
#
# Описание:
# Вы анализируете датасет с данными о пробках в городе и хотите понять, как они распределены во времени и пространстве.
# Требования:
#
# Используйте датасет Uber Movement Data или NYC Taxi Trips.
# Постройте графики:
#
# Линейный график количества поездок по часам/дням недели.
# Анимированную карту пробок с помощью plotly.express.scatter_geo + animation_frame.
#
# Проанализируйте:
#
# Пиковые часы и дни недели.
# Районы с наибольшей нагрузкой.
#
# Дополнительно:
#
# Постройте корреляцию между временем суток, районом и длительностью поездки.

# %%
# https://www.kaggle.com/datasets/fivethirtyeight/uber-pickups-in-new-york-city
# https://www.kaggle.com/datasets/mysarahmadbhat/nyc-taxi-trip-duration
