# %% [markdown]
# # Первичный обзор датасета

# %% [markdown]
# ### Задание 1: Быстрый обзор структуры данных
#
# Описание:
# Вы получили новый датасет с информацией о продажах в интернет-магазине. Вам нужно быстро оценить его структуру и качество.
# Требования:
#
# Загрузите датасет (например, E-Commerce Dataset).
# Выведите:
#
# Первые 5 строк (df.head()).
# Размер датасета (df.shape).
# Типы данных (df.dtypes).
# Количество пропущенных значений (df.isna().sum()).
# Основные статистики (df.describe()).
#
# Определите, какие столбцы могут быть:
#
# Целевыми переменными.
# Категориальными признаками.
# Числовыми признаками.
#
# Напишите краткий отчёт о том, что можно сказать о датасете на данном этапе.
# Дополнительно:
#
# Проверьте датасет на наличие дубликатов (df.duplicated().sum()).

# %%
# https://www.kaggle.com/datasets/carrie1/ecommerce-data

# %% [markdown]
# ### Задание 2: Анализ пропущенных значений
# Описание:
# Вы анализируете медицинский датасет, в котором много пропущенных значений. Вам нужно понять, как их обработать.
# Требования:
#
# Используйте датасет Pima Indians Diabetes.
# Постройте таблицу с количеством пропущенных значений по каждому столбцу.
# Визуализируйте пропущенные значения с помощью missingno или seaborn.
# Предложите стратегии обработки пропущенных значений:
#
# Удаление строк/столбцов.
# Заполнение медианой/средним/модой.
# Использование алгоритмов (например, KNNImputer).
#
# Реализуйте один из предложенных методов.
# Дополнительно:
#
# Проверьте, есть ли зависимость между наличием пропущенных значений и целевой переменной.

# %%
# https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database

# %% [markdown]
# ## Профессиональные кейсы

# %% [markdown]
# ### Задание 9: Анализ аномалий
#
# Описание:
# Вы анализируете датасет с данными о транзакциях в банке. Вам нужно выявить аномальные транзакции.
# Требования:
#
# Используйте датасет Credit Card Fraud Detection.
# Постройте графики:
#
# Boxplot для анализа выбросов.
# График распределения сумм транзакций.
#
# Примените методы обнаружения аномалий:
#
# Z-score.
# IQR (Interquartile Range).
# DBSCAN.
#
# Визуализируйте обнаруженные аномалии.
# Дополнительно:
#
# Постройте график ROC-кривой для оценки качества обнаружения аномалий.

# %%
# https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud

# %% [markdown]
# ### Задание 10: Сравнение распределений до и после обработки данных
#
# Описание:
# Вы обработали датасет (заполнили пропуски, удалили выбросы, нормализовали данные). Вам нужно визуализировать, как изменились распределения признаков.
# Требования:
#
# Используйте датасет Adult Income.
# Постройте графики распределений до и после обработки:
#
# Гистограммы.
# Boxplot.
# Q-Q plot.
#
# Сравните распределения и сделайте выводы о том, как обработка данных повлияла на их форму.
# Дополнительно:
#
# Постройте графики для анализа изменения корреляций между признаками.
