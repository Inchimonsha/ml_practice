# %% [markdown]
# ## Парсинг страницы с цитатами
#
# Напиши паука, который собирает цитаты и авторов с сайта quotes.toscrape.com. Используй Scrapy Items для структурированного сохранения текста, автора и тегов, реализуй пагинацию

# %% [markdown]
# ## Парсинг каталога книг
#
# Создай Scrapy-проект для сбора информации о книгах (название, цена, рейтинг, наличие на складе) с сайта books.toscrape.com. Собери данные для всех книг во всех категориях и сохрани в CSV или JSON
#
# Развитие: Добавь обработку картинок (например, скачивание обложек), реализуй Item Pipeline

# %% [markdown]
# ## Сохранение данных в базу
#
# Модифицируй существующий Scrapy-проект для сохранения данных о товарах/книгах в SQLite или Postgres через Scrapy Pipelines

# %% [markdown]
# ## Парсинг интернет-магазина
#
# Спарси структуру каталога, переходя по разделам и страницам товаров (название, цена, ссылка, рейтинг, количество отзывов, наличие). Реализуй обход пагинации, работай с Xpath/CSS-селекторами, сохраняй картинки.

# %% [markdown]
# ## Сбор вакансий с джоб-бордов
#
# Собери список вакансий с сайтов (HeadHunter, Indeed, LinkedIn), включая название, город, требования и зарплату. Добавь фильтрацию по ключевым словам или городам

# %% [markdown]
# ## Агрегация новостей
#
# Реализуй агрегатор новостей с разносайтов — собирай заголовки, дату, ссылку на статью. Сделай вывод в общий JSON/CSV для последующего анализа трендов тематики

# %% [markdown]
# ## Анализ отзывов о товарах
#
# Собери отзывы о продуктах (например, с Amazon — название товара, имя пользователя, дата, оценка, текст отзыва), сохрани структуру nested Items/Fields.

# %% [markdown]
# ## Мониторинг цен на авиабилеты или отели
#
# Реализуй паука для отслеживания изменения цен авиабилетов, отелей или товаров. Сохраняй историю изменений для дальнейшей визуализации или аналитики

# %% [markdown]
# ## Синхронный сбор данных с прокси и user-agent rotation
#
# Применяй прокси, fake headers и ротацию User-Agent для обхода антибот-защиты при массовом парсинге данных (например, создание ценового агрегатора из нескольких магазинов)

# %% [markdown]
# ## Скрапинг с авторизацией
#
# Научись логиниться на сайты (login form, session handling) и собирать закрытые для гостей данные (например — история заказов, личный кабинет).

# %% [markdown]
# # Проектные задачи

# %% [markdown]
# ## Поисковый агрегатор научных публикаций
#
# Собери информацию о новых статьях из arXiv, Google Scholar, ResearchGate (название, авторы, ссылки), реализуй фильтрацию по тематикам

# %% [markdown]
# ## Агрегатор волонтёрских проектов
#
# Собери волонтёрские программы с разных некоммерческих сайтов и посади их в единый каталог по странам, типам, дате проведения

# %% [markdown]
# ## Языковой хаб
#
# Собери ресурсы для изучения иностранных языков: словари, грамматические справки, подборки подкастов и видеоуроков из разных источников, реализуй фильтрацию по языку и уровню

# %% [markdown]
# # Интеграция Scrapy и автоматизация

# %% [markdown]
# ## Деплой и периодический запуск пауков
#
# Научиcь деплоить/запускать Scrapy-проекты на сервере или облаке (scrapyd, Scrapy Cloud), сделай расписание для периодического сбора новых данных

# %% [markdown]
# ## Построение пайплайна обработки данных
#
# После сбора данных из интернета обрабатывай и передавай их сразу в очереди (например, RabbitMQ/Kafka) или облачные базы для последующего анализа или ML-проекта
