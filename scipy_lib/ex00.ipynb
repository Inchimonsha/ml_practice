# %% [markdown]
# # 1. scipy.linalg (Линейная алгебра)
#
# ## Задание 1: Решение систем линейных уравнений
#
# Описание:
# Вы анализируете систему уравнений, описывающую баланс ресурсов в производственной цепочке. Вам нужно найти оптимальное распределение ресурсов.
# Требования:
#
# Задайте матрицу коэффициентов AAA и вектор правых частей bbb для системы из 3–5 уравнений.
# Решите систему с помощью scipy.linalg.solve.
# Проверьте корректность решения, подставив результат обратно в уравнения.
# Визуализируйте решение (например, если система двумерная, постройте графики уравнений и точку решения).
# Дополнительно:
#
# Используйте scipy.linalg.lstsq для решения переопределённой системы.
#
#
#
# ## Задание 2: Собственные значения и векторы
#
# Описание:
# Вы анализируете ковариационную матрицу признаков датасета и хотите понять её структуру.
# Требования:
#
# Используйте датасет Iris или Wine.
# Постройте ковариационную матрицу признаков.
# Найдите собственные значения и векторы с помощью scipy.linalg.eig.
# Визуализируйте собственные векторы и объясните их геометрический смысл.
# Дополнительно:
#
# Сравните результаты с numpy.linalg.eig и объясните различия.
#
# https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_wine.html
#
# ## Задание 3: Сингулярное разложение (SVD)
#
# Описание:
# Вы хотите применить SVD для снижения размерности данных.
# Требования:
#
# Используйте датасет Digits.
# Примените SVD (scipy.linalg.svd) к матрице признаков.
# Постройте график объяснённой дисперсии и определите оптимальное число сингулярных чисел для снижения размерности.
# Визуализируйте данные в пространстве первых двух сингулярных векторов.
# Дополнительно:
#
# Сравните результаты с PCA из sklearn.decomposition.PCA.
#
# https://scikit-learn.org/stable/auto_examples/datasets/plot_digits_last_image.html
#
# # 2. scipy.optimize (Оптимизация)
#
# ## Задание 4: Минимизация функции
#
# Описание:
# Вы хотите найти оптимальные параметры функции потерь для линейной регрессии.
# Требования:
#
# Сгенерируйте синтетические данные для линейной регрессии.
# Определите функцию потерь (MSE) как функцию от весов модели.
# Найдите оптимальные веса с помощью:
#
# scipy.optimize.minimize (метод 'BFGS').
# scipy.optimize.least_squares.
#
# Сравните результаты с аналитическим решением (нормальное уравнение).
# Дополнительно:
#
# Добавьте L2-регуляризацию и повторите оптимизацию.
#
#
#
# ## Задание 5: Подбор параметров нелинейной модели
#
# Описание:
# Вы хотите подогнать нелинейную модель (например, логистическую кривую) к данным.
# Требования:
#
# Используйте датасет о росте популяции или сгенерируйте синтетические данные для логистической кривой.
# Определите функцию логистической кривой:
# f(t)=K1+e−r(t−t0)   f(t) = \frac{K}{1 + e^{-r(t - t_0)}}f(t)=1+e−r(t−t0​)K​
#
# Подберите параметры KKK, rrr, t0t_0t0​ с помощью scipy.optimize.curve_fit.
# Визуализируйте исходные данные и подогнанную кривую.
# Дополнительно:
#
# Оцените доверительные интервалы для параметров.
#
#
#
# ## Задание 6: Линейное программирование
#
# Описание:
# Вы хотите оптимизировать распределение бюджета на рекламу для максимизации охвата.
# Требования:
#
# Задайте целевую функцию (максимизация охвата) и ограничения (бюджет, минимальный охват в каждом канале).
# Решите задачу с помощью scipy.optimize.linprog.
# Визуализируйте оптимальное распределение бюджета.
# Дополнительно:
#
# Добавьте ограничения на максимальный бюджет в каждом канале.
#
#
#
# # 3. scipy.stats (Статистика)
#
# ## Задание 7: Проверка статистических гипотез
#
# Описание:
# Вы хотите проверить, отличаются ли средние значения двух групп (например, конверсия в контрольной и тестовой группах A/B-теста).
# Требования:
#
# Используйте датасет A/B Testing или сгенерируйте синтетические данные.
# Проверьте гипотезу о равенстве средних с помощью:
#
# scipy.stats.ttest_ind (t-тест Стьюдента).
# scipy.stats.mannwhitneyu (критерий Манна-Уитни).
#
# Визуализируйте распределения групп и результаты тестов.
# Дополнительно:
#
# Проверьте нормальность распределений с помощью scipy.stats.shapiro.
#
# https://www.kaggle.com/datasets/rakannimer/ab-testing
#
# ## Задание 8: Корреляционный анализ
#
# Описание:
# Вы анализируете зависимость между признаками в датасете.
# Требования:
#
# Используйте датасет Boston Housing или Auto MPG.
# Рассчитайте корреляции Пирсона и Спирмена:
#
# scipy.stats.pearsonr
# scipy.stats.spearmanr
#
# Визуализируйте корреляционную матрицу с помощью seaborn.heatmap.
# Объясните, когда следует использовать каждый тип корреляции.
# Дополнительно:
#
# Проверьте значимость корреляций.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_boston.html
#
# https://archive.ics.uci.edu/ml/datasets/auto+mpg
#
# ## Задание 9: Подгонка распределений
#
# Описание:
# Вы хотите определить, какому распределению соответствуют ваши данные.
# Требования:
#
# Используйте датасет Income Evaluation или сгенерируйте данные.
# Подгоните несколько распределений (нормальное, экспоненциальное, гамма) с помощью scipy.stats.fit.
# Визуализируйте гистограмму данных и плотности подогнанных распределений.
# Сравните распределения с помощью критерия Колмогорова-Смирнова (scipy.stats.kstest).
# Дополнительно:
#
# Используйте scipy.stats.probplot для визуальной оценки соответствия нормальному распределению.
#
# https://archive.ics.uci.edu/ml/datasets/Adult
#
# # 4. scipy.signal (Обработка сигналов)
#
# ## Задание 10: Фильтрация временных рядов
#
# Описание:
# Вы хотите удалить шум из временного ряда.
# Требования:
#
# Используйте датасет Air Passengers или сгенерируйте синтетический сигнал с шумом.
# Примените фильтр:
#
# Скользящее среднее (scipy.signal.convolve).
# Фильтр Баттерворта (scipy.signal.butter, scipy.signal.filtfilt).
#
# Визуализируйте исходный и отфильтрованный сигналы.
# Дополнительно:
#
# Примените вейвлет-преобразование (pywt) для удаления шума.
#
# https://datamarket.com/data/set/22u3/air-passengers
#
# ## Задание 11: Спектральный анализ
#
# Описание:
# Вы анализируете частотные компоненты сигнала.
# Требования:
#
# Используйте датасет ECG Data или сгенерируйте сигнал.
# Постройте спектр сигнала с помощью:
#
# scipy.signal.periodogram
# scipy.fft.fft
#
# Визуализируйте спектр и выделите доминирующие частоты.
# Дополнительно:
#
# Примените оконные функции (scipy.signal.windows) для уменьшения артефактов.
#
# https://www.kaggle.com/datasets/shayanfazeli/heartbeat
#
# ## Задание 12: Детекция пиков
#
# Описание:
# Вы хотите найти пики в сигнале (например, в данных о продажах).
# Требования:
#
# Используйте датасет Stock Prices или сгенерируйте данные.
# Найдите пики с помощью scipy.signal.find_peaks.
# Визуализируйте сигнал и найденные пики.
# Дополнительно:
#
# Настройте параметры height и distance для фильтрации пиков.
#
# https://finance.yahoo.com/
#
# # 5. scipy.sparse (Разреженные матрицы)
#
# ## Задание 13: Работа с разреженными данными
#
# Описание:
# Вы работаете с большими разреженными матрицами (например, матрицей признаков для текстов).
# Требования:
#
# Используйте датасет 20 Newsgroups и преобразуйте тексты в TF-IDF матрицу.
# Преобразуйте матрицу в разреженный формат (scipy.sparse.csr_matrix).
# Выполните операции:
#
# Умножение на вектор.
# Транспонирование.
# Сложение матриц.
#
# Сравните использование памяти для плотной и разреженной матриц.
# Дополнительно:
#
# Решите систему линейных уравнений с разреженной матрицей (scipy.sparse.linalg.spsolve).
#
# https://scikit-learn.org/stable/datasets/real_world.html#the-20-newsgroups-text-dataset
#
# ## Задание 14: Кластеризация с разреженными матрицами
#
# Описание:
# Вы хотите кластеризовать документы, представленные в виде разреженной матрицы.
# Требования:
#
# Используйте TF-IDF матрицу из предыдущего задания.
# Примените кластеризацию K-Means (sklearn.cluster.KMeans) к разреженной матрице.
# Визуализируйте кластеры с помощью PCA или t-SNE.
# Дополнительно:
#
# Сравните качество кластеризации с плотной матрицей.
#
#
# # 6. scipy.integrate (Интегрирование)
#
# ## Задание 15: Численное интегрирование
#
# Описание:
# Вы хотите вычислить площадь под кривой плотности распределения.
# Требования:
#
# Задайте функцию плотности нормального распределения.
# Вычислите интеграл с помощью:
#
# scipy.integrate.quad
# scipy.integrate.simps
#
# Визуализируйте функцию и заштрихуйте площадь под кривой.
# Дополнительно:
#
# Вычислите интеграл от 0 до 1 для функции f(x)=sin⁡(x)/xf(x) = \sin(x)/xf(x)=sin(x)/x.
#
#
#
# ## Задание 16: Решение дифференциальных уравнений
#
# Описание:
# Вы моделируете динамику популяции с помощью уравнения Лотки-Вольтерры.
# Требования:
#
# Задайте систему дифференциальных уравнений:
# dxdt=αx−βxy   \frac{dx}{dt} = \alpha x - \beta xydtdx​=αx−βxy
# dydt=δxy−γy   \frac{dy}{dt} = \delta xy - \gamma ydtdy​=δxy−γy
#
# Решите систему с помощью scipy.integrate.odeint.
# Визуализируйте динамику популяций xxx и yyy.
# Дополнительно:
#
# Исследуйте влияние параметров α,β,δ,γ\alpha, \beta, \delta, \gammaα,β,δ,γ на динамику.
#
#
#
# # 7. scipy.interpolate (Интерполяция)
#
# ## Задание 17: Интерполяция данных
#
# Описание:
# Вы хотите восстановить пропущенные значения во временном ряде.
# Требования:
#
# Используйте датасет Temperature Data или сгенерируйте данные с пропусками.
# Примените интерполяцию:
#
# Линейная (scipy.interpolate.interp1d).
# Кубическая (scipy.interpolate.CubicSpline).
#
# Визуализируйте исходные данные и интерполированные значения.
# Дополнительно:
#
# Сравните результаты с простым заполнением средним.
#
# https://www.kaggle.com/datasets/selfishgene/historical-hourly-weather-data
#
# ## Задание 18: Двумерная интерполяция
#
# Описание:
# Вы визуализируете поверхность по разреженным данным.
# Требования:
#
# Сгенерируйте двумерные данные (например, высоты местности).
# Постройте интерполяцию с помощью scipy.interpolate.griddata.
# Визуализируйте поверхность с помощью matplotlib.pyplot.contourf.
# Дополнительно:
#
# Примените радиальную базисную интерполяцию (scipy.interpolate.Rbf).
#
#
#
# # 8. scipy.spatial (Пространственные данные)
#
# ## Задание 19: Поиск ближайших соседей
#
# Описание:
# Вы хотите найти ближайшие точки интереса для каждого клиента.
# Требования:
#
# Сгенерируйте координаты клиентов и точек интереса (магазины, банкоматы).
# Найдите ближайшие точки с помощью scipy.spatial.KDTree.
# Визуализируйте клиентов и ближайшие точки на карте (matplotlib или folium).
# Дополнительно:
#
# Оцените среднее расстояние до ближайшей точки.
#
#
#
# ## Задание 20: Триангуляция Делоне
#
# Описание:
# Вы хотите построить триангуляцию для визуализации пространственных данных.
# Требования:
#
# Сгенерируйте набор точек на плоскости.
# Постройте триангуляцию Делоне с помощью scipy.spatial.Delaunay.
# Визуализируйте триангуляцию с помощью matplotlib.pyplot.triplot.
# Дополнительно:
#
# Раскрасьте треугольники в зависимости от площади.
#
#
#
# ## Задание 21: Вычисление расстояний
#
# Описание:
# Вы хотите кластеризовать объекты на основе расстояний между ними.
# Требования:
#
# Используйте датасет Iris.
# Вычислите матрицу расстояний с помощью scipy.spatial.distance.pdist и scipy.spatial.distance.squareform.
# Примените иерархическую кластеризацию (scipy.cluster.hierarchy) и визуализируйте дендрограмму.
# Дополнительно:
#
# Сравните результаты с K-Means.
#
# https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html
#
# # 9. scipy.fft (Быстрое преобразование Фурье)
#
# ## Задание 22: Анализ частот сигнала
#
# Описание:
# Вы анализируете аудиосигнал и хотите выделить доминирующие частоты.
# Требования:
#
# Используйте аудиофайл или сгенерируйте сигнал с несколькими частотами.
# Примените БПФ с помощью scipy.fft.fft.
# Визуализируйте спектр амплитуд и выделите доминирующие частоты.
# Дополнительно:
#
# Примените оконную функцию (scipy.signal.windows.hann) перед БПФ.
#
#
#
# ## Задание 23: Фильтрация сигнала в частотной области
#
# Описание:
# Вы хотите удалить высокочастотный шум из сигнала.
# Требования:
#
# Сгенерируйте сигнал с шумом.
# Примените БПФ, обнулите высокочастотные компоненты и выполните обратное преобразование (scipy.fft.ifft).
# Визуализируйте исходный и отфильтрованный сигналы.
# Дополнительно:
#
# Реализуйте полосовой фильтр.
#
#
#
# # 10. scipy.special (Специальные функции)
#
# ## Задание 24: Использование специальных функций
#
# Описание:
# Вы хотите вычислить специальные математические функции для анализа данных.
# Требования:
#
# Вычислите значения следующих функций для заданного диапазона аргументов:
#
# Гамма-функция (scipy.special.gamma).
# Функция ошибок (scipy.special.erf).
# Полиномы Лежандра (scipy.special.legendre).
#
# Визуализируйте графики функций.
# Дополнительно:
#
# Примените функцию Бесселя (scipy.special.jn) для моделирования волновых процессов.
#
#
#
# ## Задание 25: Применение специальных функций в статистике
#
# Описание:
# Вы хотите использовать специальные функции для вычисления статистических распределений.
# Требования:
#
# Вычислите функцию распределения и плотность для:
#
# Бета-распределения (scipy.special.betainc).
# Гамма-распределения (scipy.special.gammainc).
#
# Визуализируйте результаты.
# Дополнительно:
#
# Сравните с реализацией из scipy.stats.

# %% [markdown]
# добавить задания по другим аспектам SciPy (например, работа с изображениями, оптимизация для больших данных, использование scipy.ndimage)
